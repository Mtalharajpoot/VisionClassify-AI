# %% [markdown]
# # CIFAR-10 CNN Image Classification
#
# A step-by-step TensorFlow/Keras implementation of the supplied CNN guide.

# %% [markdown]
# ## 1. Import Libraries
#
# TensorFlow = deep-learning framework; Keras = neural-network interface; NumPy = arrays; Matplotlib = plots/images.

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 2. Download CIFAR-10 and Inspect Shapes

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
print(train_images.shape)
print(train_labels.shape)
print(test_images.shape)
print(test_labels.shape)

# %% [markdown]
# Expected shapes are approximately `(50000, 32, 32, 3)`, `(50000, 1)`, `(10000, 32, 32, 3)`, `(10000, 1)`.

# %% [markdown]
# ## 3. Understand the Classes

# %%
class_names = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
plt.imshow(train_images[0])
plt.title(class_names[train_labels[0][0]])
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(8,8))
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.imshow(train_images[i])
    plt.title(class_names[train_labels[i][0]])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Normalize Images
#
# Convert pixel values from 0–255 to 0–1.

# %%
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# %% [markdown]
# ## 5. Build the CNN
#
# Architecture: Input → Conv2D(32) → MaxPool → Conv2D(64) → MaxPool → Conv2D(64) → Flatten → Dense(64) → Dense(10).

# %%
model = models.Sequential([
    layers.Input(shape=(32, 32, 3)),
    layers.Conv2D(32, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])
model.summary()

# %% [markdown]
# ## 6. Compile the Model

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## 7. Train the CNN
#
# 10 epochs, batch size 64, validation split 0.2.

# %%
history = model.fit(
    train_images,
    train_labels,
    epochs=10,
    batch_size=64,
    validation_split=0.2
)

# %% [markdown]
# ## 8. Plot Training Performance

# %%
plt.figure()
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## 9. Test the Model
#
# Training learns; validation monitors development; test data provides the final independent evaluation.

# %%
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print('Test Accuracy:', test_accuracy)

# %% [markdown]
# ## 10. Make a Prediction

# %%
predictions = model.predict(test_images)
i = 10
predicted_class = np.argmax(predictions[i])
actual_class = test_labels[i][0]
plt.imshow(test_images[i])
plt.title(f'Actual: {class_names[actual_class]}\nPredicted: {class_names[predicted_class]}')
plt.axis('off')
plt.show()

# %% [markdown]
# ## 11. Save the Trained Model

# %%
model.save('cifar10_cnn.keras')

# %% [markdown]
# ## Complete Pipeline
#
# IMAGE → PREPROCESSING → CNN → FEATURE EXTRACTION → CLASSIFICATION → PREDICTION
